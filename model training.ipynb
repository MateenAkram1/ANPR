# %%
import os
home = os.getcwd()
print(home)
# Out:
# /content

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.5/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {home}

# !yolo task=detect mode=predict model=yolo12s.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv12s summary (fused): 159 layers, 9,261,840 parameters, 0 gradients, 21.4 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 handbag, 51.7ms
# Speed: 1.9ms preprocess, 51.7ms inference, 179.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !mkdir {home}/datasets
# %cd {home}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="coyvlaOQptR9e9QMRRVg")
project = rf.workspace("test1-nhan8").project("license-plate-2pmbw")
version = project.version(1)
dataset = version.download("yolov12")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# %cd {home}

# !yolo task=detect mode=train model=yolo12s.pt data=/content/datasets/License-plate-1/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# /content
# Ultralytics 8.3.170 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train/weights/best.pt')
results = model.predict(source='/content/datasets/License-plate-1/test/images/Cars119_png.rf.66dc37f022ba55c59f8947cbac966762.jpg', save=True)
# Out:
# image 1/1 /content/datasets/License-plate-1/test/images/Cars119_png.rf.66dc37f022ba55c59f8947cbac966762.jpg: 640x640 3 licences, 21.5ms
# Speed: 2.1ms preprocess, 21.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5

# %%
from google.colab import files
files.download("/content/runs/detect/train/weights/best.pt")
